# %%
from edm_python.edm import EDM_Record
from edm_python.parsers import EDM_Parser
import json

# %%
with open("new_test.json", "r") as file:
    data = json.loads(file.read())

# %%
data
# Out:
# {'provided_cho': {'id': 'file:///Users/gregorpirgie/code/nhm/edm-python/#tms_95957',
#   'edm_type': 'IMAGE',
#   'dc_contributor': None,
#   'dc_coverage': None,
#   'dc_creator': ['Carl Fahringer'],
#   'dc_date': None,
#   'dc_description': None,
#   'dc_format': None,
#   'dc_identifier': ['39452', 'Albertina_tms_95957', 'tms_95957'],
#   'dc_language': ['de'],
#   'dc_publisher': ['Albertina, Wien, Österreich'],
#   'dc_relation': None,
#   'dc_rights': ['Albertina, Wien, Österreich'],
#   'dc_source': None,
#   'dc_subject': ['http://vocab.getty.edu/aat/300033973'],
#   'dc_title': ['Skizzenbuch zu Gerlachs Jugendbücher'],
#   'dc_type': None,
#   'dcterms_alternative': None,
#   'dcterms_conformsTo': None,
#   'dcterms_created': None,
#   'dcterms_extent': None,
#   'dcterms_hasFormat': None,
#   'dcterms_hasPart': None,
#   'dcterms_hasVersion': None,
#   'dcterms_isFormatOf': None,
#   'dcterms_isPartOf': ['Graphische Sammlung'],
#   'dcterms_isReferencedBy': None,
#   'dcterms_isReplacedBy': None,
#   'dcterms_isRequiredBy': None,
#   'dcterms_issued': None,
#   'dcterms_isVersionOf': None,
#   'dcterms_medium': None,
#   'dcterms_provenance': None,
#   'dcterms_references': None,
#   'dcterms_replaces': None,
#   'dcterms_requires': None,
#   'dcterms_spatial': ['Österreich'],
#   'dcterms_tableOfContents': None,
#   'dcterms_temporal': None,
#   'edm_currentLocation': None,
#   'edm_hasMet': None,
#   'edm_hasType': None,
#   'edm_incorporates': None,
#   'edm_isDerivativeOf': None,
#   'edm_IsNextInSequence': None,
#   'edm_isRelatedTo': None,
#   'edm_isRepresentationOf': None,
#   'edm_isSimilarTo': None,
#   'edm_isSuccessorOf': None,
#   'edm_realizes': None,
#   'owl_isSameAs': None},
#  'aggregation': {'id': 'file:///Users/gregorpirgie/code/nhm/edm-python/#tms_95957_AGG',
#   'edm_aggregatedCHO': 'file:///Users/gregorpirgie/code/nhm/edm-python/#tms_95957',
#   'edm_dataProvider': 'Albertina, Wien, Österreich',
#   'edm_provider': 'Kulturpool',
#   'edm_rights': 'http://example.com/placeholder_rights',
#   'edm_hasView': ['https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_0_DV.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_1.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_10.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_11.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_12.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_13.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_14.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_15.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_16.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_17.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_18.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_19.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_2.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_20.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_21.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_22.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_23.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_24.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_25.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_26.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_27.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_28.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_29.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_3.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_30.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_31.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_32.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_33.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_34.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_35.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_36.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_37.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_38.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_39.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_4.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_40.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_41.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_42.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_43.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_44.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_45.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_46.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_47.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_48.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_49.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_5.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_50.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_51.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_52.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_53.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_54.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_55.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_56.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_57.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_58.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_59.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_6.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_60.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_61.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_62.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_63.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_64.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_65.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_66.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_67.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_68.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_69.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_7.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_70.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_71.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_72.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_73.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_74.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_75.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_76.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_77.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_78.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_79.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_8.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_80.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_81.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_82.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_83.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_84.jpg&cache=yes',
#    'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_9.jpg&cache=yes'],
#   'edm_isShownAt': 'https://sammlungenonline.albertina.at/?query=search=/record/objectnumbersearch=[39452]&showtype=record',
#   'edm_isShownBy': 'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_0_DV.jpg&cache=yes',
#   'edm_object': 'https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_0_DV.jpg&cache=yes&maxwidth=400',
#   'dc_rights': None,
#   'edm_ugc': None,
#   'edm_intermediateProvider': None},
#  'web_resource': [{'id': "(rdflib.term.URIRef('https://sammlungenonline.albertina.at/cc/imageproxy.ashx?server=localhost&port=15001&filename=images/39452_0_DV.jpg&cache=yes'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.europeana.eu/schemas/edm/WebResource'))",
#    'dc_creator': None,
#    'dc_description': None,
#    'dc_format': None,
#    'dc_rights': None,
#    'dc_source': None,
#    'dc_type': None,
#    'dcterms_conformsTo': None,
#    'dcterms_created': None,
#    'dcterms_extent': None,
#    'dcterms_hasPart': None,
#    'dcterms_isFormatOf': None,
#    'dcterms_isPartOf': None,
#    'dcterms_isReferencedBy': None,
#    'dcterms_issued': None,
#    'edm_isNextInSequence': None,
#    'edm_rights': None,
#    'owl_sameAs': None,
#    'svcs_has_service': None,
#    'dcterms_IsReferencedBy': None}],
#  'skos_concept': [{'id': 'http://vocab.getty.edu/aat/300033973',
#    'skos_prefLabel': 'drawings (visual works)',
#    'skos_altLabel': ['Zeichnung',
#     'Zeichnungen',
#     'drawing (visual work)',
#     'dibujo',
#     'dessin (visual work)',
#     'disegno (visual work)',
#     'tekening',
#     'desenho (obra visual)',
#     'teckning'],
#    'skos_broader': ['http://vocab.getty.edu/aat/300191086'],
#    'skos_narrower': None,
#    'skos_related': None,
#    'skos_broadMatch': None,
#    'skos_narrowMatch': None,
#    'skos_relatedMatch': None,
#    'skos_exactMatch': None,
#    'skos_closeMatch': None,
#    'skos_note': ['Visuelles Werk, das durch Zeichnen hergestellt wurde, was das Auftragen von Linien auf eine Oberfläche ist, oft Papier, unter Verwendung eines Bleistifts, einer Feder, Kreide oder eines anderen Zeichenmittels, mit dem Schwerpunkt eher auf der Darstellung der Form als der Betonung der Farbe. Der Begriff wird oft allgemein definiert und auch auf computergenerierte Bilder angewendet.',
#     'Visual works produced by drawing, which is the application of lines on a surface, often paper, by using a pencil, pen, chalk, or some other tracing instrument to focus on the delineation of form rather than the application of color. This term is often defined broadly to refer to computer-generated images as well.',
#     'Imágenes producidas por el dibujo, que es la aplicación de líneas sobre una superficie, a menudo papel, usando un bolígrado, lápiz, tiza u otro instrumento de trazado para obtener un delineado de la forma en vez de la aplicación del color.',
#     'Visuele werken die gemaakt zijn door te tekenen, wat wil zeggen de toepassing van lijnen op een oppervlak (vaak papier) met een potlood, pen, krijt, of een ander tekeninstrument. Hierin wordt geconcentreerd op de afbakening van de vorm en minder op de kleurgeving.',
#     'Trabalhos visuais produzidos por desenho, que é a aplicação de linhas em uma superfície, geralmente papel, usando um lápis, caneta, giz ou algum outro instrumento de traçado para focar no delineamento da forma ao invés da aplicação da cor. Este termo é frequentemente definido de forma ampla para se referir também a imagens geradas por computador.'],
#    'skos_notation': None,
#    'skos_inScheme': None}],
#  'edm_agent': [],
#  'edm_time_span': [],
#  'edm_place': [],
#  'cc_license': [],
#  'svcs_service': [{'id': 'https://sammlungenonline.albertina.at/iiif%2Fimages%2f39452_0_DV.jpg',
#    'dcterms_conformsTo': ['http://iiif.io/api/image'],
#    'doap_implements': 'http://iiif.io/api/image/2/level2.json'}]}

# %%
test = EDM_Record(**data)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 test = EDM_Record(**data)
#
# File ~/code/nhm/edm-python/.venv/lib/python3.12/site-packages/pydantic/main.py:171, in BaseModel.__init__(self, **data)
#     169 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     170 __tracebackhide__ = True
# --> 171 self.__pydantic_validator__.validate_python(data, self_instance=self)
#
# ValidationError: 142 validation errors for EDM_Record
# provided_cho.edm_type
#   Input should be an instance of Literal [type=is_instance_of, input_value='IMAGE', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_creator.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[Literal]
#   Input should be an instance of Literal [type=is_instance_of, input_value='Carl Fahringer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_creator.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[URIRef]
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Carl Fahringer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_creator.list[is-instance[URIRef]].0
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Carl Fahringer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_creator.list[is-instance[Literal]].0
#   Input should be an instance of Literal [type=is_instance_of, input_value='Carl Fahringer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_identifier.0
#   Input should be an instance of Literal [type=is_instance_of, input_value='39452', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_identifier.1
#   Input should be an instance of Literal [type=is_instance_of, input_value='Albertina_tms_95957', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_identifier.2
#   Input should be an instance of Literal [type=is_instance_of, input_value='tms_95957', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_language.0
#   Input should be an instance of Literal [type=is_instance_of, input_value='de', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_publisher.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[Literal]
#   Input should be an instance of Literal [type=is_instance_of, input_value='Albertina, Wien, Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_publisher.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[URIRef]
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Albertina, Wien, Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_publisher.list[is-instance[URIRef]].0
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Albertina, Wien, Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_publisher.list[is-instance[Literal]].0
#   Input should be an instance of Literal [type=is_instance_of, input_value='Albertina, Wien, Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_rights.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[Literal]
#   Input should be an instance of Literal [type=is_instance_of, input_value='Albertina, Wien, Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_rights.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[URIRef]
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Albertina, Wien, Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_rights.list[is-instance[URIRef]].0
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Albertina, Wien, Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_rights.list[is-instance[Literal]].0
#   Input should be an instance of Literal [type=is_instance_of, input_value='Albertina, Wien, Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_subject.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[Literal]
#   Input should be an instance of Literal [type=is_instance_of, input_value='http://vocab.getty.edu/aat/300033973', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_subject.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[URIRef]
#   Input should be an instance of URIRef [type=is_instance_of, input_value='http://vocab.getty.edu/aat/300033973', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_subject.list[is-instance[URIRef]].0
#   Input should be an instance of URIRef [type=is_instance_of, input_value='http://vocab.getty.edu/aat/300033973', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_subject.list[is-instance[Literal]].0
#   Input should be an instance of Literal [type=is_instance_of, input_value='http://vocab.getty.edu/aat/300033973', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dc_title.0
#   Input should be an instance of Literal [type=is_instance_of, input_value='Skizzenbuch zu Gerlachs Jugendbücher', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dcterms_isPartOf.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[Literal]
#   Input should be an instance of Literal [type=is_instance_of, input_value='Graphische Sammlung', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dcterms_isPartOf.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[URIRef]
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Graphische Sammlung', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dcterms_isPartOf.list[is-instance[URIRef]].0
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Graphische Sammlung', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dcterms_isPartOf.list[is-instance[Literal]].0
#   Input should be an instance of Literal [type=is_instance_of, input_value='Graphische Sammlung', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dcterms_spatial.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[Literal]
#   Input should be an instance of Literal [type=is_instance_of, input_value='Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dcterms_spatial.list[union[is-instance[Literal],is-instance[URIRef]]].0.is-instance[URIRef]
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dcterms_spatial.list[is-instance[URIRef]].0
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# provided_cho.dcterms_spatial.list[is-instance[Literal]].0
#   Input should be an instance of Literal [type=is_instance_of, input_value='Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_aggregatedCHO
#   Input should be an instance of URIRef [type=is_instance_of, input_value='file:///Users/gregorpirg...m/edm-python/#tms_95957', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_dataProvider.is-instance[Literal]
#   Input should be an instance of Literal [type=is_instance_of, input_value='Albertina, Wien, Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_dataProvider.is-instance[URIRef]
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Albertina, Wien, Österreich', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_provider.is-instance[Literal]
#   Input should be an instance of Literal [type=is_instance_of, input_value='Kulturpool', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_provider.is-instance[URIRef]
#   Input should be an instance of URIRef [type=is_instance_of, input_value='Kulturpool', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_rights
#   Input should be an instance of URIRef [type=is_instance_of, input_value='http://example.com/placeholder_rights', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.0
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...9452_0_DV.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.1
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...s/39452_1.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.2
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_10.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.3
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_11.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.4
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_12.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.5
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_13.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.6
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_14.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.7
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_15.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.8
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_16.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.9
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_17.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.10
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_18.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.11
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_19.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.12
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...s/39452_2.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.13
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_20.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.14
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_21.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.15
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_22.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.16
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_23.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.17
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_24.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.18
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_25.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.19
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_26.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.20
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_27.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.21
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_28.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.22
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_29.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.23
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...s/39452_3.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.24
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_30.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.25
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_31.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.26
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_32.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.27
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_33.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.28
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_34.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.29
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_35.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.30
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_36.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.31
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_37.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.32
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_38.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.33
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_39.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.34
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...s/39452_4.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.35
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_40.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.36
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_41.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.37
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_42.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.38
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_43.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.39
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_44.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.40
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_45.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.41
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_46.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.42
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_47.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.43
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_48.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.44
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_49.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.45
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...s/39452_5.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.46
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_50.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.47
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_51.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.48
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_52.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.49
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_53.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.50
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_54.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.51
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_55.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.52
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_56.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.53
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_57.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.54
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_58.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.55
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_59.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.56
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...s/39452_6.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.57
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_60.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.58
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_61.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.59
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_62.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.60
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_63.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.61
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_64.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.62
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_65.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.63
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_66.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.64
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_67.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.65
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_68.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.66
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_69.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.67
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...s/39452_7.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.68
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_70.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.69
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_71.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.70
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_72.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.71
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_73.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.72
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_74.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.73
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_75.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.74
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_76.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.75
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_77.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.76
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_78.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.77
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_79.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.78
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...s/39452_8.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.79
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_80.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.80
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_81.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.81
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_82.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.82
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_83.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.83
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline.../39452_84.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_hasView.84
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...s/39452_9.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_isShownAt
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...[39452]&showtype=record', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_isShownBy
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...9452_0_DV.jpg&cache=yes', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# aggregation.edm_object
#   Input should be an instance of URIRef [type=is_instance_of, input_value='https://sammlungenonline...&cache=yes&maxwidth=400', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_prefLabel
#   Input should be an instance of Literal [type=is_instance_of, input_value='drawings (visual works)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_altLabel.0
#   Input should be an instance of Literal [type=is_instance_of, input_value='Zeichnung', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_altLabel.1
#   Input should be an instance of Literal [type=is_instance_of, input_value='Zeichnungen', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_altLabel.2
#   Input should be an instance of Literal [type=is_instance_of, input_value='drawing (visual work)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_altLabel.3
#   Input should be an instance of Literal [type=is_instance_of, input_value='dibujo', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_altLabel.4
#   Input should be an instance of Literal [type=is_instance_of, input_value='dessin (visual work)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_altLabel.5
#   Input should be an instance of Literal [type=is_instance_of, input_value='disegno (visual work)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_altLabel.6
#   Input should be an instance of Literal [type=is_instance_of, input_value='tekening', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_altLabel.7
#   Input should be an instance of Literal [type=is_instance_of, input_value='desenho (obra visual)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_altLabel.8
#   Input should be an instance of Literal [type=is_instance_of, input_value='teckning', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_broader.0
#   Input should be an instance of URIRef [type=is_instance_of, input_value='http://vocab.getty.edu/aat/300191086', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_note.0
#   Input should be an instance of Literal [type=is_instance_of, input_value='Visuelles Werk, das durc...erte Bilder angewendet.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_note.1
#   Input should be an instance of Literal [type=is_instance_of, input_value='Visual works produced by...nerated images as well.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_note.2
#   Input should be an instance of Literal [type=is_instance_of, input_value='Imágenes producidas por... aplicación del color.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_note.3
#   Input should be an instance of Literal [type=is_instance_of, input_value='Visuele werken die gemaa...nder op de kleurgeving.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# skos_concept.0.skos_note.4
#   Input should be an instance of Literal [type=is_instance_of, input_value='Trabalhos visuais produz...geradas por computador.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# svcs_service.0.dcterms_conformsTo.0
#   Input should be an instance of URIRef [type=is_instance_of, input_value='http://iiif.io/api/image', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
# svcs_service.0.doap_implements
#   Input should be an instance of URIRef [type=is_instance_of, input_value='http://iiif.io/api/image/2/level2.json', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.6/v/is_instance_of
